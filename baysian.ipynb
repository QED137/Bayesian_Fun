# %%
'''import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets
from ipywidgets import interactive
from IPython.display import display

# Function for Bayesian update and plotting
def bayesian_update(prior_mean, prior_std, likelihood_mean, likelihood_std, data_size):
    # Generate data
    data = np.random.normal(likelihood_mean, likelihood_std, data_size)
    
    # Prior distribution
    prior = stats.norm(prior_mean, prior_std)
    
    # Likelihood function
    likelihood = stats.norm(likelihood_mean, likelihood_std)
    
    # Posterior distribution parameters (for a normal-normal model)
    posterior_mean = (prior_mean / (prior_std ** 2) + np.sum(data) / (likelihood_std ** 2)) / (1 / (prior_std ** 2) + len(data) / (likelihood_std ** 2))
    posterior_std = np.sqrt(1 / (1 / (prior_std ** 2) + len(data) / (likelihood_std ** 2)))
    posterior = stats.norm(posterior_mean, posterior_std)
    
    # Plotting
    x = np.linspace(-10, 10, 1000)
    plt.figure(figsize=(10, 6))
    plt.plot(x, prior.pdf(x), label='Prior', color='blue')
    plt.plot(x, likelihood.pdf(x), label='Likelihood', color='green')
    plt.plot(x, posterior.pdf(x), label='Posterior', color='red')
    plt.hist(data, bins=30, density=True, alpha=0.5, label='Data')
    plt.legend()
    plt.title('Bayesian Update')
    plt.xlabel('Parameter value')
    plt.ylabel('Density')
    plt.show()
    
    return posterior_mean, posterior_std

# Create widgets
prior_mean_slider = widgets.FloatSlider(value=0, min=-5, max=5, step=0.1, description='Prior Mean:')
prior_std_slider = widgets.FloatSlider(value=1, min=0.1, max=5, step=0.1, description='Prior Std:')
likelihood_mean_slider = widgets.FloatSlider(value=0, min=-5, max=5, step=0.1, description='Likelihood Mean:')
likelihood_std_slider = widgets.FloatSlider(value=1, min=0.1, max=5, step=0.1, description='Likelihood Std:')
data_size_slider = widgets.IntSlider(value=100, min=10, max=500, step=10, description='Data Size:')

# Define a function to update the plot based on widget values
def update_plot(prior_mean, prior_std, likelihood_mean, likelihood_std, data_size):
    bayesian_update(prior_mean, prior_std, likelihood_mean, likelihood_std, data_size)

# Create interactive plot
interactive_plot = interactive(update_plot, prior_mean=prior_mean_slider, prior_std=prior_std_slider,
                               likelihood_mean=likelihood_mean_slider, likelihood_std=likelihood_std_slider,
                               data_size=data_size_slider)

# Display the interactive plot
display(interactive_plot)'''

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets
from ipywidgets import interactive
from IPython.display import display

def bayesian_update(prior_mean, prior_std, likelihood_mean, likelihood_std, data_size):
    # Generate data
    data = np.random.normal(likelihood_mean, likelihood_std, data_size)
    
    # Prior distribution
    prior = stats.norm(prior_mean, prior_std)
    
    # Likelihood function
    likelihood = stats.norm(likelihood_mean, likelihood_std)
    
    # Posterior distribution parameters (for a normal-normal model)
    posterior_mean = (prior_mean / (prior_std ** 2) + np.sum(data) / (likelihood_std ** 2)) / (1 / (prior_std ** 2) + len(data) / (likelihood_std ** 2))
    posterior_std = np.sqrt(1 / (1 / (prior_std ** 2) + len(data) / (likelihood_std ** 2)))
    posterior = stats.norm(posterior_mean, posterior_std)
    
    # Plotting
    x = np.linspace(-10, 10, 1000)
    plt.figure(figsize=(10, 6))
    plt.plot(x, prior.pdf(x), label='Prior', color='blue')
    plt.plot(x, likelihood.pdf(x), label='Likelihood', color='green')
    plt.plot(x, posterior.pdf(x), label='Posterior', color='red')
    plt.hist(data, bins=30, density=True, alpha=0.5, label='Data')
    plt.legend()
    plt.title('Bayesian Update')
    plt.xlabel('Parameter value')
    plt.ylabel('Density')
    plt.show()
    
    return posterior_mean, posterior_std

# Create widgets
prior_mean_slider = widgets.FloatSlider(value=0, min=-5, max=5, step=0.1, description='Prior Mean:')
prior_std_slider = widgets.FloatSlider(value=1, min=0.1, max=5, step=0.1, description='Prior Std:')
likelihood_mean_slider = widgets.FloatSlider(value=0, min=-5, max=5, step=0.1, description='Likelihood Mean:')
likelihood_std_slider = widgets.FloatSlider(value=1, min=0.1, max=5, step=0.1, description='Likelihood Std:')
data_size_slider = widgets.IntSlider(value=100, min=10, max=500, step=10, description='Data Size:')

# Define a function to update the plot based on widget values
def update_plot(prior_mean, prior_std, likelihood_mean, likelihood_std, data_size):
    bayesian_update(prior_mean, prior_std, likelihood_mean, likelihood_std, data_size)

# Create interactive plot
interactive_plot = interactive(update_plot, prior_mean=prior_mean_slider, prior_std=prior_std_slider,
                               likelihood_mean=likelihood_mean_slider, likelihood_std=likelihood_std_slider,
                               data_size=data_size_slider)

# Display the interactive plot
display(interactive_plot)
# Out:
# interactive(children=(FloatSlider(value=0.0, description='Prior Mean:', max=5.0, min=-5.0), FloatSlider(value=…
